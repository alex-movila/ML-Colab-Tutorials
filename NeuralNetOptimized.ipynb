# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-movila/ML-Colab-Tutorials/blob/master/NeuralNetOptimized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cupy as np

# %%
import os

def load(dataset):
    dataset_file = f"{dataset}.npz"
    if not os.path.exists(dataset_file):
        raise FileNotFoundError(f"Dataset \"{dataset}\" does not exist")
    return np.load(dataset_file)

def split_batches(batch_size, *datasets):
    res = []
    for ds in datasets:
        num_batches = int(np.ceil(ds.shape[0] / batch_size))
        res.append(np.array_split(ds, num_batches))
    return res

# %%
class Dense():
    def __init__(self, shape, activation=None):
        self.shape = shape
        self.biases = np.zeros((shape[1], 1))
        self.weights = np.random.randn(shape[1], shape[0]) / np.sqrt(shape[0] / 2)
        self.weighted_sums = []
        self.inputs = []
        self.bias_sensitivity = []
        self.weight_sensitivity = []

        if activation == "relu":
            self.activation = self.relu
            self.d_activation = self.d_relu
        elif activation == "sigmoid":
            self.activation = self.sigmoid
            self.d_activation = self.d_sigmoid
        elif activation == "softmax":
            self.activation = self.softmax
            self.d_activation = self.d_softmax

    def activation(self, inp):
        return inp

    def d_activation(self, inp):
        return inp

    def feedforward(self, inputs):
        self.inputs = inputs
        self.weighted_sums = np.matmul(self.weights[np.newaxis, ...], inputs) + self.biases[np.newaxis, ...]
        return self.activation(self.weighted_sums)

    def backprop(self, activation_sensitivity):
        # partial derivatives magic
        # calc how sensitive the bias is (calculate the sigmoid deriv and multiply by how sensitive the output activations are)
        if self.activation == self.softmax:
            # tranposes along the second and third axis
            self.bias_sensitivity = np.matmul(self.d_activation(self.weighted_sums), activation_sensitivity)
        else:
            self.bias_sensitivity = activation_sensitivity * self.d_activation(self.weighted_sums)

        # calc how sensitive weights are, input is transposed for matrix multiplication purposes
        self.weight_sensitivity = np.matmul(self.bias_sensitivity, self.inputs.transpose([0, 2, 1]))
        # return the sensitivity of previous activation, will be used in next layer
        return np.matmul(self.weights.transpose()[np.newaxis, ...], self.bias_sensitivity)

    def relu(self, inp):
        return inp * (inp > 0)

    def d_relu(self, inp):
        return 1. * (inp > 0)

    def sigmoid(self, z):
        return 1.0 / (1.0 + np.exp(-z))

    def d_sigmoid(self, z):
        return self.sigmoid(z) * (1 - self.sigmoid(z))

    def softmax(self, x):
        e_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return e_x / e_x.sum(axis=1, keepdims=True)

    def d_softmax(self, x):
        # jacobian matrix magic
        sm = self.softmax(x).squeeze()  # shape: (n, 10)

        # Expand sm to create a (n, 10, 1) and (n, 1, 10) for broadcasting
        sm_col = sm[:, :, np.newaxis]  # (n, 10, 1)
        sm_row = sm[:, np.newaxis, :]  # (n, 1, 10)

        # Compute Jacobian matrix for each example using broadcasting
        jacobian = sm_row * np.identity(10) - sm_col * sm_row  # (n, 10, 10)

        return jacobian

# %%
import json
import time

class Network:
    def __init__(self, cost="crossentropy"):
        self.layers = []
        self.size = []
        if cost == "MSE":
            self.cost = self.MSE
            self.d_cost = self.d_MSE
        if cost == "crossentropy":
            self.cost = self.xentropy
            self.d_cost = self.d_xentropy

    def cost(self, output, expected):
        return output

    def d_cost(self, output, expected):
        return output

    def add_layers(self, *layers):
        for l in layers:
            self.layers.append(l)
            if len(self.size) != 0:
                self.size.pop()
            self.size.append(l.shape[0])
            self.size.append(l.shape[1])

    def feedforward(self, input):
        for l in self.layers:
            input = l.feedforward(input)
        return input

    def backprop(self, output, expected):
        # calculate how sensitive the output activation is to the cost func
        activation_sensitivity = self.d_cost(output, expected)
        # loop through model, running backprop to get the gradients
        for i in range(len(self.layers) - 1, -1, -1):
            activation_sensitivity = self.layers[i].backprop(activation_sensitivity)

    def sgd(self, training_data, learn_rate, lmbda, epochs=1, validation_data=None):
        tr_x, tr_y = training_data
        previous_cost = None
        train_data_size = 0
        for t in training_data[0]:
          train_data_size += len(t)
        val_data_size = 0
        for v in validation_data[0]:
          val_data_size += len(v)

        for i in range(epochs):
            start = time.time()
            training_correct = 0
            training_total = 0
            training_cost = 0
            for batch_num in range(len(tr_x)):
                # feed data through model to calc weights, biases, activations, etc
                batch_size = tr_x[batch_num].shape[0]
                output = self.feedforward(tr_x[batch_num])
                self.backprop(output, tr_y[batch_num])
                self.update_parameters(learn_rate, lmbda, batch_size, train_data_size)

                training_correct += np.sum(np.argmax(output, axis=1) == np.argmax(tr_y[batch_num], axis=1))
                training_total += batch_size
                training_cost += np.sum(self.cost(output, tr_y[batch_num]))
                print(f"\rEpoch {i + 1}/{epochs}: ({batch_num + 1}/{len(tr_x)}) | Accuracy: {training_correct}/{training_total} | Cost: {training_cost / training_total}", end="")

            elapsed = (time.time() - start) * 1000
            print(f"\rEpoch {i + 1} Complete, Time: {round(elapsed)}ms ({round(elapsed / len(tr_x))}ms/batch), Test Accuracy: {training_correct} / {training_total}, Average Test Cost: {training_cost / training_total}", end="")
            if validation_data:
                correct, total_cost = self.evaluate(validation_data)
                avg_cost = total_cost / val_data_size
                print(f", Validation Accuracy: {correct} / {val_data_size}, Validation Average Cost = {np.round(avg_cost, 5)} {'({0:+})'.format(np.round(avg_cost - previous_cost, 5)) if previous_cost is not None else ''}", end="")
                previous_cost = avg_cost
            print()


    def update_parameters(self, learn_rate, lmbda, batch_size, total_size):
        # update weight and biases based on gradients
        for l in self.layers:
            total_bias_sens = np.sum(l.bias_sensitivity, axis=0)
            total_weight_sens = np.sum(l.weight_sensitivity, axis=0)
            l.biases -= learn_rate * (total_bias_sens / batch_size)
            l.weights -= learn_rate * (total_weight_sens / batch_size) + learn_rate * (lmbda / total_size) * l.weights

    def evaluate(self, validation_data):
        val_x, val_y = validation_data
        total_cost = 0
        total_correct = 0
        for i in range(len(validation_data[0])):
          out = self.feedforward(val_x[i])

          total_cost += np.sum(self.cost(out, val_y[i]))
          total_correct += np.sum(np.argmax(out, axis=1) == np.argmax(val_y[i], axis=1))

        return total_correct, total_cost

    def MSE(self, output, expected):
        return np.square(output - expected)

    def d_MSE(self, output, expected):
        return 2 * (output - expected)

    def xentropy(self, output, expected):
        return -expected * np.log(output)

    def d_xentropy(self, output, expected):
        return -expected/output

    def load_model(self, filename):
        f = open(filename, "r")
        data = json.load(f)
        f.close()
        if (self.size != data["sizes"]):
            raise TypeError(f"Data does not match network size of {self.size}")

        for i in range(len(data["weights"])):
            w = np.array(data["weights"][i])
            self.layers[i].weights = w

        for i in range(len(data["biases"])):
            w = np.array(data["biases"][i])
            self.layers[i].biases = w

    def export_model(self, filename):
        data = {
            "sizes": self.size,
            "weights": [l.weights.tolist() for l in self.layers],
            "biases": [l.biases.tolist() for l in self.layers]
        }

        f = open(filename, "w")
        json.dump(data, f)
        f.close()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !cp /content/drive/MyDrive/mnist.npz mnist.npz

# %%
data = load("mnist")
train_data, train_ans, test_data, test_ans = data["train_data"] / 255.0, data["train_ans"], data["test_data"] / 255.0, data["test_ans"]
train_data, train_ans = split_batches(64, train_data, train_ans)
test_data, test_ans = split_batches(100, test_data, test_ans)
print("dataset loaded")
# Out:
# dataset loaded

# %%
net = Network(cost="crossentropy")

net.add_layers(
    Dense((784, 80), activation="relu"),
    Dense((80, 80), activation="relu"),
    Dense((80, 10), activation="softmax"),
)

# net.load_model("network.json")

net.sgd((train_data, train_ans), 0.001, 0.01, epochs=100, validation_data=(test_data, test_ans))

net.export_model("network.json")
# Out:
# Epoch 1 Complete, Time: 9129ms (10ms/batch), Test Accuracy: 23282 / 60000, Average Test Cost: 1.9815222629563225, Validation Accuracy: 6290 / 10000, Validation Average Cost = 1.61146
# Epoch 2 Complete, Time: 4899ms (5ms/batch), Test Accuracy: 42047 / 60000, Average Test Cost: 1.31432902504639, Validation Accuracy: 7659 / 10000, Validation Average Cost = 1.04069 (-0.57077)
# Epoch 3 Complete, Time: 4141ms (4ms/batch), Test Accuracy: 47214 / 60000, Average Test Cost: 0.9014261853827125, Validation Accuracy: 8177 / 10000, Validation Average Cost = 0.75718 (-0.28351)
# Epoch 4 Complete, Time: 4047ms (4ms/batch), Test Accuracy: 49680 / 60000, Average Test Cost: 0.7011210269133893, Validation Accuracy: 8454 / 10000, Validation Average Cost = 0.61683 (-0.14035)
# Epoch 5 Complete, Time: 5085ms (5ms/batch), Test Accuracy: 51054 / 60000, Average Test Cost: 0.5931457802531758, Validation Accuracy: 8631 / 10000, Validation Average Cost = 0.53479 (-0.08205)
# Epoch 6 Complete, Time: 4030ms (4ms/batch), Test Accuracy: 51846 / 60000, Average Test Cost: 0.5259076742945895, Validation Accuracy: 8737 / 10000, Validation Average Cost = 0.48107 (-0.05372)
# Epoch 7 Complete, Time: 4041ms (4ms/batch), Test Accuracy: 52405 / 60000, Average Test Cost: 0.48005160458565005, Validation Accuracy: 8813 / 10000, Validation Average Cost = 0.44324 (-0.03783)
# Epoch 8 Complete, Time: 5025ms (5ms/batch), Test Accuracy: 52856 / 60000, Average Test Cost: 0.4467659794791966, Validation Accuracy: 8880 / 10000, Validation Average Cost = 0.41519 (-0.02804)
# Epoch 9 Complete, Time: 4013ms (4ms/batch), Test Accuracy: 53158 / 60000, Average Test Cost: 0.42139261868875294, Validation Accuracy: 8923 / 10000, Validation Average Cost = 0.39351 (-0.02168)
# Epoch 10 Complete, Time: 4023ms (4ms/batch), Test Accuracy: 53464 / 60000, Average Test Cost: 0.4013215525167366, Validation Accuracy: 8961 / 10000, Validation Average Cost = 0.37621 (-0.0173)
# Epoch 11 Complete, Time: 5574ms (6ms/batch), Test Accuracy: 53684 / 60000, Average Test Cost: 0.3849850109062822, Validation Accuracy: 8992 / 10000, Validation Average Cost = 0.36203 (-0.01418)
# Epoch 12 Complete, Time: 4075ms (4ms/batch), Test Accuracy: 53843 / 60000, Average Test Cost: 0.3713968217250094, Validation Accuracy: 9019 / 10000, Validation Average Cost = 0.35014 (-0.01189)
# Epoch 13 Complete, Time: 4273ms (5ms/batch), Test Accuracy: 53995 / 60000, Average Test Cost: 0.35986458783425174, Validation Accuracy: 9040 / 10000, Validation Average Cost = 0.34001 (-0.01013)
# Epoch 14 Complete, Time: 5087ms (5ms/batch), Test Accuracy: 54128 / 60000, Average Test Cost: 0.34988596874701977, Validation Accuracy: 9063 / 10000, Validation Average Cost = 0.33122 (-0.00879)
# Epoch 15 Complete, Time: 4219ms (4ms/batch), Test Accuracy: 54253 / 60000, Average Test Cost: 0.3411045533385347, Validation Accuracy: 9085 / 10000, Validation Average Cost = 0.32347 (-0.00776)
# Epoch 16 Complete, Time: 4083ms (4ms/batch), Test Accuracy: 54369 / 60000, Average Test Cost: 0.33327943070239113, Validation Accuracy: 9106 / 10000, Validation Average Cost = 0.31655 (-0.00692)
# Epoch 17 Complete, Time: 5029ms (5ms/batch), Test Accuracy: 54479 / 60000, Average Test Cost: 0.3262319371202032, Validation Accuracy: 9124 / 10000, Validation Average Cost = 0.31032 (-0.00623)
# Epoch 18 Complete, Time: 4065ms (4ms/batch), Test Accuracy: 54568 / 60000, Average Test Cost: 0.31982389599922634, Validation Accuracy: 9134 / 10000, Validation Average Cost = 0.30466 (-0.00566)
# Epoch 19 Complete, Time: 4177ms (4ms/batch), Test Accuracy: 54635 / 60000, Average Test Cost: 0.3139410244380722, Validation Accuracy: 9143 / 10000, Validation Average Cost = 0.29947 (-0.00519)
# Epoch 20 Complete, Time: 4914ms (5ms/batch), Test Accuracy: 54712 / 60000, Average Test Cost: 0.3085109726512303, Validation Accuracy: 9163 / 10000, Validation Average Cost = 0.2947 (-0.00477)
# Epoch 21 Complete, Time: 4084ms (4ms/batch), Test Accuracy: 54793 / 60000, Average Test Cost: 0.30345622200763933, Validation Accuracy: 9174 / 10000, Validation Average Cost = 0.29026 (-0.00444)
# Epoch 22 Complete, Time: 4361ms (5ms/batch), Test Accuracy: 54881 / 60000, Average Test Cost: 0.298707462799439, Validation Accuracy: 9182 / 10000, Validation Average Cost = 0.28609 (-0.00416)
# Epoch 23 Complete, Time: 4831ms (5ms/batch), Test Accuracy: 54962 / 60000, Average Test Cost: 0.29422306920230884, Validation Accuracy: 9192 / 10000, Validation Average Cost = 0.28215 (-0.00394)
# Epoch 24 Complete, Time: 4143ms (4ms/batch), Test Accuracy: 55022 / 60000, Average Test Cost: 0.28999017832775237, Validation Accuracy: 9206 / 10000, Validation Average Cost = 0.27844 (-0.00371)
# Epoch 25 Complete, Time: 4410ms (5ms/batch), Test Accuracy: 55080 / 60000, Average Test Cost: 0.28597778056794765, Validation Accuracy: 9215 / 10000, Validation Average Cost = 0.27492 (-0.00352)
# Epoch 26 Complete, Time: 4657ms (5ms/batch), Test Accuracy: 55147 / 60000, Average Test Cost: 0.2821439122591026, Validation Accuracy: 9227 / 10000, Validation Average Cost = 0.27155 (-0.00337)
# Epoch 27 Complete, Time: 4062ms (4ms/batch), Test Accuracy: 55206 / 60000, Average Test Cost: 0.27847118289124106, Validation Accuracy: 9234 / 10000, Validation Average Cost = 0.26833 (-0.00322)
# Epoch 28 Complete, Time: 4583ms (5ms/batch), Test Accuracy: 55258 / 60000, Average Test Cost: 0.2749568531603779, Validation Accuracy: 9242 / 10000, Validation Average Cost = 0.26525 (-0.00308)
# Epoch 29 Complete, Time: 4538ms (5ms/batch), Test Accuracy: 55317 / 60000, Average Test Cost: 0.27157999989876164, Validation Accuracy: 9253 / 10000, Validation Average Cost = 0.26227 (-0.00298)
# Epoch 30 Complete, Time: 4104ms (4ms/batch), Test Accuracy: 55383 / 60000, Average Test Cost: 0.2683212908434198, Validation Accuracy: 9261 / 10000, Validation Average Cost = 0.25938 (-0.00288)
# Epoch 31 Complete, Time: 4786ms (5ms/batch), Test Accuracy: 55429 / 60000, Average Test Cost: 0.2651756359074261, Validation Accuracy: 9270 / 10000, Validation Average Cost = 0.2566 (-0.00278)
# Epoch 32 Complete, Time: 4230ms (5ms/batch), Test Accuracy: 55488 / 60000, Average Test Cost: 0.2621338537347967, Validation Accuracy: 9278 / 10000, Validation Average Cost = 0.25393 (-0.00268)
# Epoch 33 Complete, Time: 4015ms (4ms/batch), Test Accuracy: 55534 / 60000, Average Test Cost: 0.2591915798822877, Validation Accuracy: 9292 / 10000, Validation Average Cost = 0.25133 (-0.00259)
# Epoch 34 Complete, Time: 4882ms (5ms/batch), Test Accuracy: 55584 / 60000, Average Test Cost: 0.2563413309734393, Validation Accuracy: 9298 / 10000, Validation Average Cost = 0.24883 (-0.0025)
# Epoch 35 Complete, Time: 4113ms (4ms/batch), Test Accuracy: 55638 / 60000, Average Test Cost: 0.25357353597885235, Validation Accuracy: 9305 / 10000, Validation Average Cost = 0.24641 (-0.00242)
# Epoch 36 Complete, Time: 4063ms (4ms/batch), Test Accuracy: 55690 / 60000, Average Test Cost: 0.25087904392844235, Validation Accuracy: 9311 / 10000, Validation Average Cost = 0.24405 (-0.00236)
# Epoch 37 Complete, Time: 5058ms (5ms/batch), Test Accuracy: 55737 / 60000, Average Test Cost: 0.24824587961708458, Validation Accuracy: 9318 / 10000, Validation Average Cost = 0.24175 (-0.0023)
# Epoch 38 Complete, Time: 4040ms (4ms/batch), Test Accuracy: 55782 / 60000, Average Test Cost: 0.24567845959166182, Validation Accuracy: 9325 / 10000, Validation Average Cost = 0.23951 (-0.00223)
# Epoch 39 Complete, Time: 4059ms (4ms/batch), Test Accuracy: 55824 / 60000, Average Test Cost: 0.24317818447755737, Validation Accuracy: 9330 / 10000, Validation Average Cost = 0.23734 (-0.00217)
# Epoch 40 Complete, Time: 5040ms (5ms/batch), Test Accuracy: 55870 / 60000, Average Test Cost: 0.24075302395506132, Validation Accuracy: 9335 / 10000, Validation Average Cost = 0.23524 (-0.0021)
# Epoch 41 Complete, Time: 4058ms (4ms/batch), Test Accuracy: 55903 / 60000, Average Test Cost: 0.2383969363811059, Validation Accuracy: 9337 / 10000, Validation Average Cost = 0.23319 (-0.00205)
# Epoch 42 Complete, Time: 4041ms (4ms/batch), Test Accuracy: 55941 / 60000, Average Test Cost: 0.2360988246468444, Validation Accuracy: 9343 / 10000, Validation Average Cost = 0.23118 (-0.00201)
# Epoch 43 Complete, Time: 6155ms (7ms/batch), Test Accuracy: 55975 / 60000, Average Test Cost: 0.23386500380897984, Validation Accuracy: 9353 / 10000, Validation Average Cost = 0.22924 (-0.00195)
# Epoch 44 Complete, Time: 4121ms (4ms/batch), Test Accuracy: 56007 / 60000, Average Test Cost: 0.2316783615764723, Validation Accuracy: 9355 / 10000, Validation Average Cost = 0.22732 (-0.00192)
# Epoch 45 Complete, Time: 4027ms (4ms/batch), Test Accuracy: 56037 / 60000, Average Test Cost: 0.22954360305237861, Validation Accuracy: 9357 / 10000, Validation Average Cost = 0.22546 (-0.00187)
# Epoch 46 Complete, Time: 4956ms (5ms/batch), Test Accuracy: 56078 / 60000, Average Test Cost: 0.22745807833213968, Validation Accuracy: 9364 / 10000, Validation Average Cost = 0.22364 (-0.00182)
# Epoch 47 Complete, Time: 4044ms (4ms/batch), Test Accuracy: 56115 / 60000, Average Test Cost: 0.2254227512627741, Validation Accuracy: 9364 / 10000, Validation Average Cost = 0.22186 (-0.00178)
# Epoch 48 Complete, Time: 4049ms (4ms/batch), Test Accuracy: 56143 / 60000, Average Test Cost: 0.2234326209057091, Validation Accuracy: 9365 / 10000, Validation Average Cost = 0.22012 (-0.00174)
# Epoch 49 Complete, Time: 4982ms (5ms/batch), Test Accuracy: 56173 / 60000, Average Test Cost: 0.22148888609216122, Validation Accuracy: 9365 / 10000, Validation Average Cost = 0.21842 (-0.0017)
# Epoch 50 Complete, Time: 4047ms (4ms/batch), Test Accuracy: 56218 / 60000, Average Test Cost: 0.21958466496447787, Validation Accuracy: 9369 / 10000, Validation Average Cost = 0.21676 (-0.00167)
# Epoch 51 Complete, Time: 4033ms (4ms/batch), Test Accuracy: 56265 / 60000, Average Test Cost: 0.2177208783654131, Validation Accuracy: 9372 / 10000, Validation Average Cost = 0.21512 (-0.00164)
# Epoch 52 Complete, Time: 4962ms (5ms/batch), Test Accuracy: 56305 / 60000, Average Test Cost: 0.2158940965580789, Validation Accuracy: 9377 / 10000, Validation Average Cost = 0.21352 (-0.0016)
# Epoch 53 Complete, Time: 4008ms (4ms/batch), Test Accuracy: 56336 / 60000, Average Test Cost: 0.2141041957483594, Validation Accuracy: 9385 / 10000, Validation Average Cost = 0.21196 (-0.00156)
# Epoch 54 Complete, Time: 4031ms (4ms/batch), Test Accuracy: 56366 / 60000, Average Test Cost: 0.2123505297926737, Validation Accuracy: 9389 / 10000, Validation Average Cost = 0.21044 (-0.00152)
# Epoch 55 Complete, Time: 4926ms (5ms/batch), Test Accuracy: 56394 / 60000, Average Test Cost: 0.2106348186109279, Validation Accuracy: 9392 / 10000, Validation Average Cost = 0.20893 (-0.0015)
# Epoch 56 Complete, Time: 4008ms (4ms/batch), Test Accuracy: 56426 / 60000, Average Test Cost: 0.20895079621861448, Validation Accuracy: 9394 / 10000, Validation Average Cost = 0.20746 (-0.00148)
# Epoch 57 Complete, Time: 4068ms (4ms/batch), Test Accuracy: 56453 / 60000, Average Test Cost: 0.20730072403407152, Validation Accuracy: 9400 / 10000, Validation Average Cost = 0.20601 (-0.00145)
# Epoch 58 Complete, Time: 4926ms (5ms/batch), Test Accuracy: 56481 / 60000, Average Test Cost: 0.20568279078193782, Validation Accuracy: 9404 / 10000, Validation Average Cost = 0.20459 (-0.00142)
# Epoch 59 Complete, Time: 4001ms (4ms/batch), Test Accuracy: 56502 / 60000, Average Test Cost: 0.20409421031049926, Validation Accuracy: 9410 / 10000, Validation Average Cost = 0.2032 (-0.00139)
# Epoch 60 Complete, Time: 4069ms (4ms/batch), Test Accuracy: 56530 / 60000, Average Test Cost: 0.20253429580884674, Validation Accuracy: 9413 / 10000, Validation Average Cost = 0.20183 (-0.00137)
# Epoch 61 Complete, Time: 4875ms (5ms/batch), Test Accuracy: 56558 / 60000, Average Test Cost: 0.20099979200968077, Validation Accuracy: 9417 / 10000, Validation Average Cost = 0.20047 (-0.00136)
# Epoch 62 Complete, Time: 4003ms (4ms/batch), Test Accuracy: 56584 / 60000, Average Test Cost: 0.19949234233282478, Validation Accuracy: 9417 / 10000, Validation Average Cost = 0.19914 (-0.00133)
# Epoch 63 Complete, Time: 4225ms (5ms/batch), Test Accuracy: 56607 / 60000, Average Test Cost: 0.19801016718443398, Validation Accuracy: 9419 / 10000, Validation Average Cost = 0.19783 (-0.00131)
# Epoch 64 Complete, Time: 4721ms (5ms/batch), Test Accuracy: 56634 / 60000, Average Test Cost: 0.1965594808095936, Validation Accuracy: 9421 / 10000, Validation Average Cost = 0.19655 (-0.00128)
# Epoch 65 Complete, Time: 4032ms (4ms/batch), Test Accuracy: 56663 / 60000, Average Test Cost: 0.19513138798190963, Validation Accuracy: 9423 / 10000, Validation Average Cost = 0.19528 (-0.00126)
# Epoch 66 Complete, Time: 4311ms (5ms/batch), Test Accuracy: 56686 / 60000, Average Test Cost: 0.19372467472894098, Validation Accuracy: 9431 / 10000, Validation Average Cost = 0.19404 (-0.00124)
# Epoch 67 Complete, Time: 4666ms (5ms/batch), Test Accuracy: 56714 / 60000, Average Test Cost: 0.1923391391036198, Validation Accuracy: 9436 / 10000, Validation Average Cost = 0.19281 (-0.00123)
# Epoch 68 Complete, Time: 4082ms (4ms/batch), Test Accuracy: 56742 / 60000, Average Test Cost: 0.19097503002407543, Validation Accuracy: 9442 / 10000, Validation Average Cost = 0.1916 (-0.00121)
# Epoch 69 Complete, Time: 4531ms (5ms/batch), Test Accuracy: 56763 / 60000, Average Test Cost: 0.18963229126162132, Validation Accuracy: 9445 / 10000, Validation Average Cost = 0.19041 (-0.0012)
# Epoch 70 Complete, Time: 4428ms (5ms/batch), Test Accuracy: 56787 / 60000, Average Test Cost: 0.18830897092376306, Validation Accuracy: 9448 / 10000, Validation Average Cost = 0.18924 (-0.00117)
# Epoch 71 Complete, Time: 4067ms (4ms/batch), Test Accuracy: 56813 / 60000, Average Test Cost: 0.18701087639736494, Validation Accuracy: 9447 / 10000, Validation Average Cost = 0.18809 (-0.00115)
# Epoch 72 Complete, Time: 4663ms (5ms/batch), Test Accuracy: 56837 / 60000, Average Test Cost: 0.1857337158771264, Validation Accuracy: 9450 / 10000, Validation Average Cost = 0.18697 (-0.00112)
# Epoch 73 Complete, Time: 4285ms (5ms/batch), Test Accuracy: 56864 / 60000, Average Test Cost: 0.1844781908644933, Validation Accuracy: 9453 / 10000, Validation Average Cost = 0.18586 (-0.00111)
# Epoch 74 Complete, Time: 4044ms (4ms/batch), Test Accuracy: 56884 / 60000, Average Test Cost: 0.18324082954343524, Validation Accuracy: 9455 / 10000, Validation Average Cost = 0.18478 (-0.00109)
# Epoch 75 Complete, Time: 4774ms (5ms/batch), Test Accuracy: 56900 / 60000, Average Test Cost: 0.18202123258605568, Validation Accuracy: 9460 / 10000, Validation Average Cost = 0.18371 (-0.00106)
# Epoch 76 Complete, Time: 4144ms (4ms/batch), Test Accuracy: 56919 / 60000, Average Test Cost: 0.1808203291262477, Validation Accuracy: 9463 / 10000, Validation Average Cost = 0.18266 (-0.00105)
# Epoch 77 Complete, Time: 4011ms (4ms/batch), Test Accuracy: 56946 / 60000, Average Test Cost: 0.17963813346667173, Validation Accuracy: 9467 / 10000, Validation Average Cost = 0.18162 (-0.00104)
# Epoch 78 Complete, Time: 4971ms (5ms/batch), Test Accuracy: 56967 / 60000, Average Test Cost: 0.17847312537938625, Validation Accuracy: 9471 / 10000, Validation Average Cost = 0.18059 (-0.00103)
# Epoch 79 Complete, Time: 4027ms (4ms/batch), Test Accuracy: 56988 / 60000, Average Test Cost: 0.17732738422192526, Validation Accuracy: 9474 / 10000, Validation Average Cost = 0.17959 (-0.00101)
# Epoch 80 Complete, Time: 4025ms (4ms/batch), Test Accuracy: 57002 / 60000, Average Test Cost: 0.17620184612513565, Validation Accuracy: 9476 / 10000, Validation Average Cost = 0.1786 (-0.00099)
# Epoch 81 Complete, Time: 5045ms (5ms/batch), Test Accuracy: 57021 / 60000, Average Test Cost: 0.17509474110238665, Validation Accuracy: 9475 / 10000, Validation Average Cost = 0.17761 (-0.00099)
# Epoch 82 Complete, Time: 4043ms (4ms/batch), Test Accuracy: 57041 / 60000, Average Test Cost: 0.17400691018977268, Validation Accuracy: 9475 / 10000, Validation Average Cost = 0.17664 (-0.00097)
# Epoch 83 Complete, Time: 4046ms (4ms/batch), Test Accuracy: 57059 / 60000, Average Test Cost: 0.1729334906967789, Validation Accuracy: 9476 / 10000, Validation Average Cost = 0.17569 (-0.00095)
# Epoch 84 Complete, Time: 5011ms (5ms/batch), Test Accuracy: 57081 / 60000, Average Test Cost: 0.17187482698528808, Validation Accuracy: 9478 / 10000, Validation Average Cost = 0.17476 (-0.00093)
# Epoch 85 Complete, Time: 4003ms (4ms/batch), Test Accuracy: 57102 / 60000, Average Test Cost: 0.17083319525518953, Validation Accuracy: 9482 / 10000, Validation Average Cost = 0.17384 (-0.00092)
# Epoch 86 Complete, Time: 4045ms (4ms/batch), Test Accuracy: 57112 / 60000, Average Test Cost: 0.1698050006963377, Validation Accuracy: 9487 / 10000, Validation Average Cost = 0.17294 (-0.0009)
# Epoch 87 Complete, Time: 4937ms (5ms/batch), Test Accuracy: 57128 / 60000, Average Test Cost: 0.168791988490232, Validation Accuracy: 9489 / 10000, Validation Average Cost = 0.17205 (-0.00088)
# Epoch 88 Complete, Time: 4017ms (4ms/batch), Test Accuracy: 57146 / 60000, Average Test Cost: 0.16778848637083257, Validation Accuracy: 9493 / 10000, Validation Average Cost = 0.17117 (-0.00088)
# Epoch 89 Complete, Time: 4004ms (4ms/batch), Test Accuracy: 57166 / 60000, Average Test Cost: 0.1667989354402781, Validation Accuracy: 9497 / 10000, Validation Average Cost = 0.17032 (-0.00086)
# Epoch 90 Complete, Time: 4963ms (5ms/batch), Test Accuracy: 57176 / 60000, Average Test Cost: 0.16582170827386408, Validation Accuracy: 9500 / 10000, Validation Average Cost = 0.16947 (-0.00085)
# Epoch 91 Complete, Time: 4076ms (4ms/batch), Test Accuracy: 57188 / 60000, Average Test Cost: 0.16485794633450326, Validation Accuracy: 9503 / 10000, Validation Average Cost = 0.16864 (-0.00083)
# Epoch 92 Complete, Time: 4048ms (4ms/batch), Test Accuracy: 57206 / 60000, Average Test Cost: 0.16390684940634326, Validation Accuracy: 9504 / 10000, Validation Average Cost = 0.16781 (-0.00083)
# Epoch 93 Complete, Time: 4939ms (5ms/batch), Test Accuracy: 57223 / 60000, Average Test Cost: 0.16296666397605103, Validation Accuracy: 9507 / 10000, Validation Average Cost = 0.167 (-0.00081)
# Epoch 94 Complete, Time: 4029ms (4ms/batch), Test Accuracy: 57238 / 60000, Average Test Cost: 0.16203919846748177, Validation Accuracy: 9507 / 10000, Validation Average Cost = 0.16619 (-0.0008)
# Epoch 95 Complete, Time: 4121ms (4ms/batch), Test Accuracy: 57252 / 60000, Average Test Cost: 0.1611236025296137, Validation Accuracy: 9508 / 10000, Validation Average Cost = 0.1654 (-0.00079)
# Epoch 96 Complete, Time: 4801ms (5ms/batch), Test Accuracy: 57268 / 60000, Average Test Cost: 0.16022060167516403, Validation Accuracy: 9511 / 10000, Validation Average Cost = 0.16462 (-0.00078)
# Epoch 97 Complete, Time: 3994ms (4ms/batch), Test Accuracy: 57287 / 60000, Average Test Cost: 0.15932969199576055, Validation Accuracy: 9516 / 10000, Validation Average Cost = 0.16385 (-0.00077)
# Epoch 98 Complete, Time: 4257ms (5ms/batch), Test Accuracy: 57308 / 60000, Average Test Cost: 0.15845025091568238, Validation Accuracy: 9518 / 10000, Validation Average Cost = 0.16308 (-0.00076)
# Epoch 99 Complete, Time: 4701ms (5ms/batch), Test Accuracy: 57322 / 60000, Average Test Cost: 0.1575829951148917, Validation Accuracy: 9522 / 10000, Validation Average Cost = 0.16233 (-0.00076)
# Epoch 100 Complete, Time: 4523ms (5ms/batch), Test Accuracy: 57342 / 60000, Average Test Cost: 0.15672478646342133, Validation Accuracy: 9525 / 10000, Validation Average Cost = 0.16158 (-0.00075)
