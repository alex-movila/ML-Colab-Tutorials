# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-movila/ML-Colab-Tutorials/blob/master/Keras_MNIST_DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
discriminator = keras.Sequential([
  keras.Input(shape=(28, 28, 1)),
  layers.Conv2D(64, (3, 3), strides=(2, 2), padding='same'),
  layers.LeakyReLU(alpha=0.2),
  layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same'),
  layers.LeakyReLU(alpha=0.2),
  layers.GlobalMaxPooling2D(),
  layers.Dense(1)
], name='discriminator')

# %%
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 64)        640
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 74,625
# Trainable params: 74,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_dim = 128

generator = keras.Sequential([
  keras.Input(shape=(latent_dim,)),
  # We want to generate 128 coefficients to reshape into a 7x7x128 map
  layers.Dense(7 * 7 * 128),
  layers.LeakyReLU(alpha=0.2),
  layers.Reshape((7, 7, 128)),
  layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'),
  layers.LeakyReLU(alpha=0.2),
  layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'),
  layers.LeakyReLU(alpha=0.2),
  layers.Conv2D(1, (7, 7), padding='same', activation='sigmoid')
], name='generator')

# %%
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6272)              809088
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 1)         6273
# =================================================================
# Total params: 1,339,905
# Trainable params: 1,339,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
d_optimizer = keras.optimizers.Adam(learning_rate=0.0003)
g_optimizer = keras.optimizers.Adam(learning_rate=0.0004)

# Instantiate a loss function.
loss_fn = keras.losses.BinaryCrossentropy(from_logits=True)

# %%
@tf.function
def train_step(real_images):
    # Sample random points in the latent space
    random_latent_vectors = tf.random.normal(shape=(batch_size, latent_dim))
    # Decode them to fake images
    generated_images = generator(random_latent_vectors)
    # Combine them with real images
    combined_images = tf.concat([generated_images, real_images], axis=0)

    # Assemble labels discriminating real from fake images
    labels = tf.concat([tf.ones((batch_size, 1)),
                        tf.zeros((real_images.shape[0], 1))], axis=0)
    # Add random noise to the labels - important trick!
    labels += 0.05 * tf.random.uniform(labels.shape)

    # Train the discriminator
    with tf.GradientTape() as tape:
      predictions = discriminator(combined_images)
      d_loss = loss_fn(labels, predictions)
    grads = tape.gradient(d_loss, discriminator.trainable_weights)
    d_optimizer.apply_gradients(zip(grads, discriminator.trainable_weights))

    # Sample random points in the latent space
    random_latent_vectors = tf.random.normal(shape=(batch_size, latent_dim))
    # Assemble labels that say "all real images"
    misleading_labels = tf.zeros((batch_size, 1))

    # Train the generator (note that we should *not* update the weights
    # of the discriminator)!
    with tf.GradientTape() as tape:
      predictions = discriminator(generator(random_latent_vectors))
      g_loss = loss_fn(misleading_labels, predictions)
    grads = tape.gradient(g_loss, generator.trainable_weights)
    g_optimizer.apply_gradients(zip(grads, generator.trainable_weights))
    return d_loss, g_loss, generated_images

# %%
# Prepare the dataset. We use both the training & test MNIST digits.
batch_size = 64
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
all_digits = np.concatenate([x_train, x_test])
all_digits = all_digits.astype('float32') / 255.
all_digits = np.reshape(all_digits, (-1, 28, 28, 1))
dataset = tf.data.Dataset.from_tensor_slices(all_digits)
dataset = dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
import os
epochs = 100
save_dir = './'

for epoch in range(epochs):
  print('\nStart epoch', epoch)

  for step, real_images in enumerate(dataset):
    # Train the discriminator & generator on one batch of real images.
    d_loss, g_loss, generated_images = train_step(real_images)

    # Occasionally save / plot.
    if step % 200 == 0:
      # Print metrics
      print('discriminator loss at step %d: %.2f' % (step, d_loss))
      print('adversarial loss at step %d: %.2f' % (step, g_loss))

      # Save one generated image
      img = tf.keras.preprocessing.image.array_to_img(
          generated_images[0] * 255., scale=False)
      img.save(os.path.join(save_dir, 'generated_img' + str(step) + '.png'))
# Out:
# Start epoch 0
# discriminator loss at step 0: 0.71
# adversarial loss at step 0: 0.72
# discriminator loss at step 200: 0.71
# adversarial loss at step 200: 1.15
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.43
# adversarial loss at step 600: 1.39
# discriminator loss at step 800: 0.47
# adversarial loss at step 800: 1.33
# discriminator loss at step 1000: 0.67
# adversarial loss at step 1000: 0.81
#
# Start epoch 1
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 0.86
# discriminator loss at step 200: 0.69
# adversarial loss at step 200: 0.70
# discriminator loss at step 400: 0.67
# adversarial loss at step 400: 0.79
# discriminator loss at step 600: 0.71
# adversarial loss at step 600: 0.87
# discriminator loss at step 800: 0.85
# adversarial loss at step 800: 0.64
# discriminator loss at step 1000: 0.72
# adversarial loss at step 1000: 0.71
#
# Start epoch 2
# discriminator loss at step 0: 0.70
# adversarial loss at step 0: 0.76
# discriminator loss at step 200: 0.71
# adversarial loss at step 200: 0.88
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 0.95
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.83
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.68
# adversarial loss at step 1000: 0.80
#
# Start epoch 3
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 0.97
# discriminator loss at step 200: 0.50
# adversarial loss at step 200: 1.09
# discriminator loss at step 400: -0.02
# adversarial loss at step 400: 6.80
# discriminator loss at step 600: 0.36
# adversarial loss at step 600: 1.71
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.76
# discriminator loss at step 1000: 0.56
# adversarial loss at step 1000: 0.95
#
# Start epoch 4
# discriminator loss at step 0: 0.56
# adversarial loss at step 0: 1.30
# discriminator loss at step 200: 0.76
# adversarial loss at step 200: 0.87
# discriminator loss at step 400: 0.58
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.68
# adversarial loss at step 600: 1.01
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.87
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.81
#
# Start epoch 5
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.01
# discriminator loss at step 200: 0.69
# adversarial loss at step 200: 0.91
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.88
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.82
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 0.86
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 0.98
#
# Start epoch 6
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.04
# discriminator loss at step 200: 0.58
# adversarial loss at step 200: 0.87
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.97
# discriminator loss at step 600: 0.55
# adversarial loss at step 600: 1.06
# discriminator loss at step 800: 0.59
# adversarial loss at step 800: 1.02
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.87
#
# Start epoch 7
# discriminator loss at step 0: 0.66
# adversarial loss at step 0: 1.06
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 0.84
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.93
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 0.93
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 0.94
#
# Start epoch 8
# discriminator loss at step 0: 0.56
# adversarial loss at step 0: 1.01
# discriminator loss at step 200: 0.68
# adversarial loss at step 200: 0.83
# discriminator loss at step 400: 0.68
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 0.81
# discriminator loss at step 1000: 0.55
# adversarial loss at step 1000: 0.94
#
# Start epoch 9
# discriminator loss at step 0: 0.66
# adversarial loss at step 0: 1.12
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 1.10
# discriminator loss at step 400: 0.54
# adversarial loss at step 400: 1.05
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 1.05
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.01
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.12
#
# Start epoch 10
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.18
# discriminator loss at step 200: 0.56
# adversarial loss at step 200: 0.96
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.90
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 0.88
# discriminator loss at step 800: 0.52
# adversarial loss at step 800: 1.14
# discriminator loss at step 1000: 0.57
# adversarial loss at step 1000: 0.97
#
# Start epoch 11
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.13
# discriminator loss at step 200: 0.48
# adversarial loss at step 200: 1.11
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.94
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.97
# discriminator loss at step 800: 0.52
# adversarial loss at step 800: 1.01
# discriminator loss at step 1000: 0.55
# adversarial loss at step 1000: 0.96
#
# Start epoch 12
# discriminator loss at step 0: 0.55
# adversarial loss at step 0: 1.19
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.93
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 1.05
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 1.03
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 1.13
# discriminator loss at step 1000: 0.53
# adversarial loss at step 1000: 1.08
#
# Start epoch 13
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.31
# discriminator loss at step 200: 0.54
# adversarial loss at step 200: 1.13
# discriminator loss at step 400: 0.57
# adversarial loss at step 400: 1.04
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.97
# discriminator loss at step 800: 0.45
# adversarial loss at step 800: 1.28
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.03
#
# Start epoch 14
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.38
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 1.08
# discriminator loss at step 400: 0.57
# adversarial loss at step 400: 1.03
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.07
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 1.26
# discriminator loss at step 1000: 0.54
# adversarial loss at step 1000: 1.00
#
# Start epoch 15
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.33
# discriminator loss at step 200: 0.56
# adversarial loss at step 200: 0.97
# discriminator loss at step 400: 0.55
# adversarial loss at step 400: 0.95
# discriminator loss at step 600: 0.53
# adversarial loss at step 600: 1.03
# discriminator loss at step 800: 0.55
# adversarial loss at step 800: 1.04
# discriminator loss at step 1000: 0.54
# adversarial loss at step 1000: 1.04
#
# Start epoch 16
# discriminator loss at step 0: 0.53
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.58
# adversarial loss at step 200: 1.05
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.15
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.98
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 1.15
# discriminator loss at step 1000: 0.54
# adversarial loss at step 1000: 0.91
#
# Start epoch 17
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.16
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.92
# discriminator loss at step 400: 0.58
# adversarial loss at step 400: 1.23
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.89
# discriminator loss at step 800: 0.56
# adversarial loss at step 800: 0.97
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.04
#
# Start epoch 18
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.27
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.85
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.95
# discriminator loss at step 600: 0.57
# adversarial loss at step 600: 0.92
# discriminator loss at step 800: 0.56
# adversarial loss at step 800: 0.81
# discriminator loss at step 1000: 0.56
# adversarial loss at step 1000: 1.02
#
# Start epoch 19
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.06
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.05
# discriminator loss at step 400: 0.57
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.89
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 1.13
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.09
#
# Start epoch 20
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.19
# discriminator loss at step 200: 0.55
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.97
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.55
# adversarial loss at step 1000: 0.97
#
# Start epoch 21
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.68
# adversarial loss at step 200: 1.01
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.03
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 0.85
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.05
# discriminator loss at step 1000: 0.59
# adversarial loss at step 1000: 0.93
#
# Start epoch 22
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.14
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.86
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 1.02
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 0.83
# discriminator loss at step 800: 0.70
# adversarial loss at step 800: 0.99
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 1.01
#
# Start epoch 23
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 0.98
# discriminator loss at step 200: 0.68
# adversarial loss at step 200: 0.84
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.87
# discriminator loss at step 800: 0.69
# adversarial loss at step 800: 0.92
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.94
#
# Start epoch 24
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.39
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.57
# adversarial loss at step 600: 0.87
# discriminator loss at step 800: 0.59
# adversarial loss at step 800: 0.81
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 0.90
#
# Start epoch 25
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.17
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 0.92
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.94
# discriminator loss at step 600: 0.67
# adversarial loss at step 600: 0.93
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.96
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 1.03
#
# Start epoch 26
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.24
# discriminator loss at step 200: 0.68
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 1.00
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 0.83
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 0.90
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 1.03
#
# Start epoch 27
# discriminator loss at step 0: 0.55
# adversarial loss at step 0: 1.26
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 1.04
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.07
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 1.09
#
# Start epoch 28
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.22
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 0.99
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.92
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 0.94
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 0.99
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.05
#
# Start epoch 29
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.59
# adversarial loss at step 200: 0.98
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.89
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.89
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.90
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 1.08
#
# Start epoch 30
# discriminator loss at step 0: 0.56
# adversarial loss at step 0: 1.27
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 1.04
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.97
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 0.97
# discriminator loss at step 800: 0.59
# adversarial loss at step 800: 0.95
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.96
#
# Start epoch 31
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.12
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.79
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.57
# adversarial loss at step 600: 1.04
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.88
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 0.96
#
# Start epoch 32
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.07
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.84
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 1.02
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.11
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 0.91
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 1.11
#
# Start epoch 33
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.31
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.05
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.00
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 0.99
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.83
# discriminator loss at step 1000: 0.65
# adversarial loss at step 1000: 0.84
#
# Start epoch 34
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.30
# discriminator loss at step 200: 0.67
# adversarial loss at step 200: 0.97
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.91
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 0.83
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 0.85
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 1.05
#
# Start epoch 35
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.29
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.05
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 1.11
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 1.05
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 0.94
#
# Start epoch 36
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.09
# discriminator loss at step 200: 0.58
# adversarial loss at step 200: 1.04
# discriminator loss at step 400: 0.68
# adversarial loss at step 400: 1.00
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.89
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.91
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 1.03
#
# Start epoch 37
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.01
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.96
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.06
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 1.07
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.89
# discriminator loss at step 1000: 0.59
# adversarial loss at step 1000: 1.02
#
# Start epoch 38
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.35
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.86
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.69
# adversarial loss at step 600: 0.99
# discriminator loss at step 800: 0.56
# adversarial loss at step 800: 1.09
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.03
#
# Start epoch 39
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.34
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.91
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 1.02
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 1.02
# discriminator loss at step 800: 0.66
# adversarial loss at step 800: 0.87
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.04
#
# Start epoch 40
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.31
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.96
# discriminator loss at step 600: 0.57
# adversarial loss at step 600: 0.91
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 0.88
#
# Start epoch 41
# discriminator loss at step 0: 0.54
# adversarial loss at step 0: 1.33
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.99
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.81
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.76
# discriminator loss at step 800: 0.59
# adversarial loss at step 800: 0.97
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 0.91
#
# Start epoch 42
# discriminator loss at step 0: 0.66
# adversarial loss at step 0: 1.17
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.96
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 1.07
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 0.87
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.95
#
# Start epoch 43
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.17
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 1.03
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.95
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 0.84
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 0.92
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.07
#
# Start epoch 44
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.22
# discriminator loss at step 200: 0.69
# adversarial loss at step 200: 1.01
# discriminator loss at step 400: 0.65
# adversarial loss at step 400: 1.05
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 1.02
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 0.94
#
# Start epoch 45
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.13
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 0.81
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.84
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 1.15
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 1.09
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 0.87
#
# Start epoch 46
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.20
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 1.10
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 0.92
#
# Start epoch 47
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.07
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.92
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.86
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 1.08
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 0.83
#
# Start epoch 48
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.97
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 1.08
# discriminator loss at step 800: 0.67
# adversarial loss at step 800: 1.02
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 1.01
#
# Start epoch 49
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.10
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.86
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.88
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 0.94
# discriminator loss at step 1000: 0.56
# adversarial loss at step 1000: 1.01
#
# Start epoch 50
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.36
# discriminator loss at step 200: 0.67
# adversarial loss at step 200: 0.92
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.85
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.88
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 0.95
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 1.06
#
# Start epoch 51
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.24
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.97
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.80
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 1.16
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 1.12
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.98
#
# Start epoch 52
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.08
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 1.10
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.09
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 1.03
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.96
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.05
#
# Start epoch 53
# discriminator loss at step 0: 0.69
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 0.83
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.82
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 1.03
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 0.96
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.12
#
# Start epoch 54
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.06
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.91
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 1.01
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 0.93
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.85
#
# Start epoch 55
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.12
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 1.09
# discriminator loss at step 400: 0.65
# adversarial loss at step 400: 0.87
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 0.85
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 1.10
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 1.12
#
# Start epoch 56
# discriminator loss at step 0: 0.67
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.01
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.92
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 0.98
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 0.91
# discriminator loss at step 1000: 0.67
# adversarial loss at step 1000: 0.84
#
# Start epoch 57
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 0.99
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 1.02
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.11
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.81
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 1.00
# discriminator loss at step 1000: 0.56
# adversarial loss at step 1000: 1.19
#
# Start epoch 58
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.30
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.07
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 1.02
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 1.03
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.07
#
# Start epoch 59
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.08
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.96
# discriminator loss at step 400: 0.65
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 0.88
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 1.01
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.09
#
# Start epoch 60
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.10
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.04
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.91
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 1.06
# discriminator loss at step 800: 0.71
# adversarial loss at step 800: 1.08
# discriminator loss at step 1000: 0.68
# adversarial loss at step 1000: 0.99
#
# Start epoch 61
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.37
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 0.83
# discriminator loss at step 400: 0.65
# adversarial loss at step 400: 1.04
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.94
# discriminator loss at step 800: 0.67
# adversarial loss at step 800: 1.19
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 0.94
#
# Start epoch 62
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.18
# discriminator loss at step 200: 0.59
# adversarial loss at step 200: 1.10
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 1.04
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 0.94
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 1.10
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 0.98
#
# Start epoch 63
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.88
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.85
# discriminator loss at step 600: 0.65
# adversarial loss at step 600: 0.91
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.21
#
# Start epoch 64
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.68
# adversarial loss at step 200: 0.84
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.87
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.96
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.87
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 1.05
#
# Start epoch 65
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.11
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.04
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 1.01
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.00
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 0.99
#
# Start epoch 66
# discriminator loss at step 0: 0.56
# adversarial loss at step 0: 1.04
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.00
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 1.08
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 1.12
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 1.42
#
# Start epoch 67
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.59
# adversarial loss at step 200: 1.00
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.92
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 1.00
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 1.07
#
# Start epoch 68
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.36
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.97
# discriminator loss at step 400: 0.67
# adversarial loss at step 400: 0.93
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.00
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 1.02
# discriminator loss at step 1000: 0.57
# adversarial loss at step 1000: 0.98
#
# Start epoch 69
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.08
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 0.93
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 1.17
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 0.86
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 1.14
#
# Start epoch 70
# discriminator loss at step 0: 0.67
# adversarial loss at step 0: 1.22
# discriminator loss at step 200: 0.59
# adversarial loss at step 200: 0.93
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 0.95
# discriminator loss at step 600: 0.65
# adversarial loss at step 600: 1.07
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.01
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 1.04
#
# Start epoch 71
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.29
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 0.82
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.91
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 1.00
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 1.08
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 0.95
#
# Start epoch 72
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.16
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.91
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 1.08
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 0.85
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.97
# discriminator loss at step 1000: 0.58
# adversarial loss at step 1000: 0.96
#
# Start epoch 73
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.19
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.08
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 1.12
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.97
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 1.08
# discriminator loss at step 1000: 0.68
# adversarial loss at step 1000: 0.97
#
# Start epoch 74
# discriminator loss at step 0: 0.65
# adversarial loss at step 0: 1.22
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.88
# discriminator loss at step 400: 0.68
# adversarial loss at step 400: 0.99
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 0.98
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 1.06
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 1.26
#
# Start epoch 75
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.33
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.02
# discriminator loss at step 600: 0.65
# adversarial loss at step 600: 0.93
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 1.23
# discriminator loss at step 1000: 0.63
# adversarial loss at step 1000: 0.90
#
# Start epoch 76
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.11
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.94
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.96
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 1.00
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 1.09
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.99
#
# Start epoch 77
# discriminator loss at step 0: 0.54
# adversarial loss at step 0: 1.21
# discriminator loss at step 200: 0.70
# adversarial loss at step 200: 0.78
# discriminator loss at step 400: 0.68
# adversarial loss at step 400: 1.17
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 1.19
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.97
# discriminator loss at step 1000: 0.70
# adversarial loss at step 1000: 1.10
#
# Start epoch 78
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.23
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.09
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 0.86
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.96
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.97
#
# Start epoch 79
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.22
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.99
# discriminator loss at step 400: 0.58
# adversarial loss at step 400: 1.06
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 0.98
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 1.15
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 1.00
#
# Start epoch 80
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.38
# discriminator loss at step 200: 0.55
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.97
# discriminator loss at step 600: 0.64
# adversarial loss at step 600: 1.03
# discriminator loss at step 800: 0.61
# adversarial loss at step 800: 1.01
# discriminator loss at step 1000: 0.56
# adversarial loss at step 1000: 0.93
#
# Start epoch 81
# discriminator loss at step 0: 0.62
# adversarial loss at step 0: 1.27
# discriminator loss at step 200: 0.63
# adversarial loss at step 200: 1.05
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.59
# adversarial loss at step 600: 0.98
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 0.94
# discriminator loss at step 1000: 0.57
# adversarial loss at step 1000: 0.90
#
# Start epoch 82
# discriminator loss at step 0: 0.53
# adversarial loss at step 0: 1.20
# discriminator loss at step 200: 0.58
# adversarial loss at step 200: 1.02
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.90
# discriminator loss at step 600: 0.65
# adversarial loss at step 600: 0.97
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 0.84
# discriminator loss at step 1000: 0.53
# adversarial loss at step 1000: 1.13
#
# Start epoch 83
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.17
# discriminator loss at step 200: 0.64
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 0.88
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 0.92
# discriminator loss at step 800: 0.56
# adversarial loss at step 800: 1.17
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 0.97
#
# Start epoch 84
# discriminator loss at step 0: 0.58
# adversarial loss at step 0: 1.15
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.93
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.90
# discriminator loss at step 600: 0.62
# adversarial loss at step 600: 1.00
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.57
# adversarial loss at step 1000: 0.92
#
# Start epoch 85
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.20
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 0.94
# discriminator loss at step 400: 0.62
# adversarial loss at step 400: 0.90
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 1.05
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 0.90
#
# Start epoch 86
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.25
# discriminator loss at step 200: 0.57
# adversarial loss at step 200: 1.02
# discriminator loss at step 400: 0.55
# adversarial loss at step 400: 0.85
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 1.17
# discriminator loss at step 800: 0.65
# adversarial loss at step 800: 1.07
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.92
#
# Start epoch 87
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.11
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 1.00
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.80
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.96
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 1.12
# discriminator loss at step 1000: 0.62
# adversarial loss at step 1000: 0.94
#
# Start epoch 88
# discriminator loss at step 0: 0.59
# adversarial loss at step 0: 1.37
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 1.10
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 1.03
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.05
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 1.12
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 0.93
#
# Start epoch 89
# discriminator loss at step 0: 0.60
# adversarial loss at step 0: 1.31
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 1.14
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 0.92
# discriminator loss at step 800: 0.66
# adversarial loss at step 800: 1.10
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 1.18
#
# Start epoch 90
# discriminator loss at step 0: 0.54
# adversarial loss at step 0: 0.95
# discriminator loss at step 200: 0.62
# adversarial loss at step 200: 1.06
# discriminator loss at step 400: 0.69
# adversarial loss at step 400: 1.05
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.91
# discriminator loss at step 800: 0.64
# adversarial loss at step 800: 0.89
# discriminator loss at step 1000: 0.64
# adversarial loss at step 1000: 0.94
#
# Start epoch 91
# discriminator loss at step 0: 0.56
# adversarial loss at step 0: 1.42
# discriminator loss at step 200: 0.57
# adversarial loss at step 200: 1.07
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.94
# discriminator loss at step 600: 0.63
# adversarial loss at step 600: 1.01
# discriminator loss at step 800: 0.58
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.67
# adversarial loss at step 1000: 0.96
#
# Start epoch 92
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.16
# discriminator loss at step 200: 0.58
# adversarial loss at step 200: 1.03
# discriminator loss at step 400: 0.59
# adversarial loss at step 400: 0.90
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.90
# discriminator loss at step 800: 0.66
# adversarial loss at step 800: 1.26
# discriminator loss at step 1000: 0.60
# adversarial loss at step 1000: 1.13
#
# Start epoch 93
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.39
# discriminator loss at step 200: 0.65
# adversarial loss at step 200: 0.89
# discriminator loss at step 400: 0.64
# adversarial loss at step 400: 0.92
# discriminator loss at step 600: 0.61
# adversarial loss at step 600: 1.07
# discriminator loss at step 800: 0.60
# adversarial loss at step 800: 1.32
# discriminator loss at step 1000: 0.69
# adversarial loss at step 1000: 1.07
#
# Start epoch 94
# discriminator loss at step 0: 0.55
# adversarial loss at step 0: 1.40
# discriminator loss at step 200: 0.56
# adversarial loss at step 200: 0.88
# discriminator loss at step 400: 0.58
# adversarial loss at step 400: 1.10
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.83
# discriminator loss at step 800: 0.67
# adversarial loss at step 800: 1.23
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 1.12
#
# Start epoch 95
# discriminator loss at step 0: 0.64
# adversarial loss at step 0: 1.24
# discriminator loss at step 200: 0.66
# adversarial loss at step 200: 1.10
# discriminator loss at step 400: 0.61
# adversarial loss at step 400: 0.79
# discriminator loss at step 600: 0.56
# adversarial loss at step 600: 1.13
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 0.99
# discriminator loss at step 1000: 0.59
# adversarial loss at step 1000: 1.06
#
# Start epoch 96
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.04
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 0.90
# discriminator loss at step 400: 0.67
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.60
# adversarial loss at step 600: 0.95
# discriminator loss at step 800: 0.63
# adversarial loss at step 800: 0.91
# discriminator loss at step 1000: 0.59
# adversarial loss at step 1000: 1.02
#
# Start epoch 97
# discriminator loss at step 0: 0.61
# adversarial loss at step 0: 1.28
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 0.96
# discriminator loss at step 400: 0.66
# adversarial loss at step 400: 1.09
# discriminator loss at step 600: 0.66
# adversarial loss at step 600: 0.96
# discriminator loss at step 800: 0.57
# adversarial loss at step 800: 0.99
# discriminator loss at step 1000: 0.66
# adversarial loss at step 1000: 0.90
#
# Start epoch 98
# discriminator loss at step 0: 0.57
# adversarial loss at step 0: 1.45
# discriminator loss at step 200: 0.60
# adversarial loss at step 200: 0.86
# discriminator loss at step 400: 0.60
# adversarial loss at step 400: 0.98
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.93
# discriminator loss at step 800: 0.66
# adversarial loss at step 800: 1.11
# discriminator loss at step 1000: 0.61
# adversarial loss at step 1000: 1.11
#
# Start epoch 99
# discriminator loss at step 0: 0.63
# adversarial loss at step 0: 1.10
# discriminator loss at step 200: 0.61
# adversarial loss at step 200: 1.12
# discriminator loss at step 400: 0.63
# adversarial loss at step 400: 1.01
# discriminator loss at step 600: 0.58
# adversarial loss at step 600: 0.95
# discriminator loss at step 800: 0.62
# adversarial loss at step 800: 0.98
# discriminator loss at step 1000: 0.65
# adversarial loss at step 1000: 0.81
